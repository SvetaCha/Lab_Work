# %% [markdown]
# # **1.Markdown Cell**
#
# * Hi! Its Main Academy?
# * All HTML tabs are supported!
# * Моя сторінка на лінкедін [Лінкедін](https://www.linkedin.com/in/sveta-cha-73a18265/)

# %% [markdown]
# # This is Heading 1

# %% [markdown]
# ## This is Heading 2

# %% [markdown]
# some gray colored text:
#
# >This is where we can bring quotes and present them nicely

# %% [markdown]
# And this is the paragraph about something very important. Even math:

# %% [markdown]
# ![math](https://render.githubusercontent.com/render/math?math=y_%7Bsub%7D%20%3D%20%5Csqrt%7Bx_%7Bsub%7D%7D&mode=display)

# %% [markdown]
# Or python code example:

# %% [markdown]
#     import math
#     def foo():
#         return "foo"

# %% [markdown]
# Here is the sample mean:

# %% [markdown]
# ![math](https://render.githubusercontent.com/render/math?math=%5Cbar%7By%7D%20%3D%20%5Cfrac%7B1%7D%7Bn%7D%5Csum_%7Bi%3D1%7D%5E%7Bn%7Dy_i&mode=display)

# %% [markdown]
# Here is the sample variance:

# %% [markdown]
# ![math](https://render.githubusercontent.com/render/math?math=%5Csigma%5E2%20%3D%20%5Cfrac%7B%5Csum_%7Bi%3D1%7D%5E%7Bn%7D%28y_i-%5Cbar%7By%7D%29%5E2%7D%7Bn-1%7D&mode=display)

# %% [markdown]
# Here is the sample standard deviation:

# %% [markdown]
# ![math](https://render.githubusercontent.com/render/math?math=%5Csigma%20%3D%20%5Csqrt%7B%5Cfrac%7B%5Csum_%7Bi%3D1%7D%5E%7Bn%7D%28y_i-%5Cbar%7By%7D%29%5E2%7D%7Bn-1%7D%7D&mode=display)
